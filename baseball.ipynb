# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/Users/alexcarr/Desktop/SA Grind/2025_hitter_stats.csv')

# %%
df.head()
# Out:
#     Rk             Player   Age Team   Lg  WAR      G     PA     AB      R  \
# 0  1.0  Francisco Lindor#  31.0  NYM   NL  5.9  160.0  732.0  644.0  117.0
# 1  2.0     Rafael Devers*  28.0  2TM  2LG  4.1  163.0  729.0  607.0   99.0
# 2  2.0     Rafael Devers*  28.0  BOS   AL  2.3   73.0  334.0  272.0   47.0
# 3  2.0     Rafael Devers*  28.0  SFG   NL  1.9   90.0  395.0  335.0   52.0
# 4  3.0     Shohei Ohtani*  30.0  LAD   NL  6.6  158.0  727.0  611.0  146.0
#
#    ...  Rbat+     TB  GIDP   HBP   SH   SF   IBB     Pos     Awards  \
# 0  ...  128.0  300.0   9.0  16.0  0.0  7.0   2.0   *6/DH   ASMVP-10
# 1  ...  139.0  291.0  16.0   6.0  0.0  4.0  10.0  *D3/5H        NaN
# 2  ...  153.0  137.0   7.0   4.0  0.0  2.0   7.0       D        NaN
# 3  ...  127.0  154.0   9.0   2.0  0.0  2.0   3.0   D3/5H        NaN
# 4  ...  175.0  380.0   9.0   3.0  0.0  2.0  20.0     *D1  ASMVP-1SS
#
#    Player-additional
# 0          lindofr01
# 1          deverra01
# 2          deverra01
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'Team', 'Lg', 'WAR', 'G', 'PA', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG',
#        'OPS', 'OPS+', 'rOBA', 'Rbat+', 'TB', 'GIDP', 'HBP', 'SH', 'SF', 'IBB',
#        'Pos', 'Awards', 'Player-additional'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Rk         Age         WAR           G          PA          AB  \
# count  922.000000  922.000000  922.000000  922.000000  922.000000  922.000000
# mean   377.392625   28.183297    0.681453   61.578091  218.991323  195.917570
# std    212.740859    3.559945    1.515892   52.365239  216.435936  192.951243
# min      1.000000   20.000000   -1.800000    1.000000    0.000000    0.000000
# 25%    193.250000   26.000000   -0.200000   13.250000   31.000000   29.000000
# 50%    381.500000   28.000000    0.100000   48.000000  136.500000  123.000000
# 75%    554.750000   30.000000    1.100000  107.750000  387.750000  344.000000
# max    763.000000   41.000000    9.700000  163.000000  732.000000  652.000000
#
#                 R           H          2B         3B  ...         OPS  \
# count  922.000000  922.000000  922.000000  922.00000  ...  831.000000
# mean    25.704989   47.838395    9.234273    0.72885  ...    0.619158
# ...

# %%
df[['H', 'HR']].corr()
# Out:
#            H        HR
# H   1.000000  0.838799
# HR  0.838799  1.000000

# %%
df.shape
# Out:
# (923, 35)

# %%
df.nlargest(5, 'HR')[['Player', 'WAR', 'HR']]
# Out:
#              Player  WAR    HR
# 12     Cal Raleigh#  7.4  60.0
# 6   Kyle Schwarber*  4.6  56.0
# 4    Shohei Ohtani*  6.6  55.0
# 25      Aaron Judge  9.7  53.0
# 36   Eugenio Suárez  3.6  49.0

# %%
df.plot.scatter(x='H', y='HR')
# Out:
# <Axes: xlabel='H', ylabel='HR'>

# %%
df[df['HR']>20]
# Out:
#         Rk              Player   Age Team   Lg  WAR      G     PA     AB  \
# 0      1.0   Francisco Lindor#  31.0  NYM   NL  5.9  160.0  732.0  644.0
# 1      2.0      Rafael Devers*  28.0  2TM  2LG  4.1  163.0  729.0  607.0
# 4      3.0      Shohei Ohtani*  30.0  LAD   NL  6.6  158.0  727.0  611.0
# 5      4.0         Matt Olson*  31.0  ATL   NL  6.0  162.0  724.0  624.0
# 6      5.0     Kyle Schwarber*  32.0  PHI   NL  4.6  162.0  724.0  604.0
# ..     ...                 ...   ...  ...  ...  ...    ...    ...    ...
# 241  204.0       Wilyer Abreu*  26.0  BOS   AL  3.2  115.0  417.0  373.0
# 245  208.0    Ronald Acuña Jr.  27.0  ATL   NL  3.0   95.0  412.0  338.0
# 255  218.0       Matt Wallner*  27.0  MIN   AL  0.6  104.0  392.0  336.0
# 344  289.0  Colson Montgomery*  23.0  CHW   AL  3.3   71.0  284.0  255.0
# 349  294.0   Giancarlo Stanton  35.0  NYY   AL  1.9   77.0  281.0  249.0
#
#          R  ...  Rbat+     TB  GIDP   HBP   SH   SF   IBB     Pos      Awards  \
# ...

# %%
df.sort_values('HR', ascending=False).head(10)[['Player', 'HR']]
# Out:
#               Player    HR
# 12      Cal Raleigh#  60.0
# 6    Kyle Schwarber*  56.0
# 4     Shohei Ohtani*  55.0
# 25       Aaron Judge  53.0
# 36    Eugenio Suárez  49.0
# 45   Junior Caminero  45.0
# 8         Juan Soto*  43.0
# 10       Pete Alonso  38.0
# 100         Jo Adell  37.0
# 177      Nick Kurtz*  36.0

# %%
df['BB+IBB'] = df['BB']+ df['IBB']
df.head(5)
# Out:
#     Rk             Player   Age Team   Lg  WAR      G     PA     AB      R  \
# 0  1.0  Francisco Lindor#  31.0  NYM   NL  5.9  160.0  732.0  644.0  117.0
# 1  2.0     Rafael Devers*  28.0  2TM  2LG  4.1  163.0  729.0  607.0   99.0
# 2  2.0     Rafael Devers*  28.0  BOS   AL  2.3   73.0  334.0  272.0   47.0
# 3  2.0     Rafael Devers*  28.0  SFG   NL  1.9   90.0  395.0  335.0   52.0
# 4  3.0     Shohei Ohtani*  30.0  LAD   NL  6.6  158.0  727.0  611.0  146.0
#
#    ...     TB  GIDP   HBP   SH   SF   IBB     Pos     Awards  \
# 0  ...  300.0   9.0  16.0  0.0  7.0   2.0   *6/DH   ASMVP-10
# 1  ...  291.0  16.0   6.0  0.0  4.0  10.0  *D3/5H        NaN
# 2  ...  137.0   7.0   4.0  0.0  2.0   7.0       D        NaN
# 3  ...  154.0   9.0   2.0  0.0  2.0   3.0   D3/5H        NaN
# 4  ...  380.0   9.0   3.0  0.0  2.0  20.0     *D1  ASMVP-1SS
#
#    Player-additional  BB+IBB
# 0          lindofr01    67.0
# 1          deverra01   122.0
# 2          deverra01    63.0
# ...

# %%
df.groupby('Team')['HR'].sum().sort_values(ascending=False)
# Out:
# Team
# 2TM    505.0
# NYY    274.0
# LAD    244.0
# SEA    238.0
# LAA    226.0
# NYM    224.0
# CHC    223.0
# ATH    219.0
# ARI    214.0
# PHI    212.0
# DET    198.0
# BAL    191.0
# TOR    191.0
# MIN    191.0
# ATL    190.0
# BOS    186.0
# HOU    182.0
# TBR    182.0
# TEX    175.0
# SFG    173.0
# CLE    168.0
# CIN    167.0
# MIL    166.0
# CHW    165.0
# WSN    161.0
# COL    160.0
# KCR    159.0
# MIA    154.0
# SDP    152.0
# STL    148.0
# PIT    117.0
# 3TM      0.0
# Name: HR, dtype: float64

# %%
df['HR'].mean()
# Out:
# 6.6757049891540134

# %%
df['HR'].median()
# Out:
# 3.0

# %%
hundredgames = df[df['G'] >= 100]
hundredgames['HR'].mean()
# Out:
# 17.374517374517374

# %%
hundredgames['HR'].std()
# Out:
# 10.372644369670553

# %%
# players more than 2 standard deviations from the mean using a filter expression
hundredgames[hundredgames['HR'] > hundredgames['HR'].mean() + 2 * hundredgames['HR'].std()]
# Out:
#       Rk           Player   Age Team   Lg  WAR      G     PA     AB      R  \
# 4    3.0   Shohei Ohtani*  30.0  LAD   NL  6.6  158.0  727.0  611.0  146.0
# 6    5.0  Kyle Schwarber*  32.0  PHI   NL  4.6  162.0  724.0  604.0  111.0
# 8    7.0       Juan Soto*  26.0  NYM   NL  6.2  160.0  715.0  577.0  120.0
# 12  11.0     Cal Raleigh#  28.0  SEA   AL  7.4  159.0  705.0  596.0  110.0
# 25  24.0      Aaron Judge  33.0  NYY   AL  9.7  152.0  679.0  541.0  137.0
# 36  35.0   Eugenio Suárez  33.0  2TM  2LG  3.6  159.0  657.0  588.0   91.0
# 45  42.0  Junior Caminero  21.0  TBR   AL  4.4  154.0  653.0  602.0   93.0
#
#     ...  Rbat+     TB  GIDP   HBP   SH   SF   IBB     Pos     Awards  \
# 4   ...  175.0  380.0   9.0   3.0  0.0  2.0  20.0     *D1  ASMVP-1SS
# 6   ...  149.0  340.0   4.0  11.0  0.0  1.0   6.0    *D/7    ASMVP-2
# 8   ...  163.0  303.0  17.0   3.0  1.0  6.0  13.0    *9/D    MVP-3SS
# 12  ...  165.0  351.0   6.0   9.0  0.0  3.0  17.0   *2D/H  ASMVP-2SS
# ...

# %%
hundredgames['HR'].hist(bins=10)
# bins = number of bars in the histogram
plt.xlabel('Home Runs') 
plt.ylabel('Frequency')
plt.title('Distribution of Home Runs')
# Out:
# Text(0.5, 1.0, 'Distribution of Home Runs')

# %%
df['HR'].corr(df['IBB'])
# Out:
# 0.6049744984433059

# %%
df.corr(numeric_only=True)
# Out:
#              Rk       Age       WAR         G        PA        AB         R  \
# Rk     1.000000  0.012257 -0.623175 -0.920950 -0.915136 -0.914752 -0.871706
# Age    0.012257  1.000000 -0.018202 -0.023651 -0.032311 -0.037788 -0.037481
# WAR   -0.623175 -0.018202  1.000000  0.665376  0.726355  0.714430  0.814421
# G     -0.920950 -0.023651  0.665376  1.000000  0.978261  0.978914  0.933488
# PA    -0.915136 -0.032311  0.726355  0.978261  1.000000  0.998783  0.968385
# AB    -0.914752 -0.037788  0.714430  0.978914  0.998783  1.000000  0.962756
# R     -0.871706 -0.037481  0.814421  0.933488  0.968385  0.962756  1.000000
# H     -0.896084 -0.034658  0.762273  0.957991  0.988179  0.989420  0.967404
# 2B    -0.862988 -0.043105  0.734206  0.921381  0.950325  0.952070  0.930515
# 3B    -0.463194 -0.147583  0.443121  0.509621  0.523824  0.527926  0.547522
# HR    -0.755706  0.005780  0.754909  0.801712  0.851422  0.843535  0.894498
# ...

# %%
df.plot.scatter(x='H', y='TB')
# Out:
# <Axes: xlabel='H', ylabel='TB'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
# SQL Query:
# SELECT Player, Team, HR
# FROM df
# WHERE HR > 20
# ORDER BY HR DESC
df[df['HR'] > 20][['Player', 'Team', 'HR']].sort_values('HR', ascending=False)
# Out:
#                  Player Team    HR
# 12         Cal Raleigh#  SEA  60.0
# 6       Kyle Schwarber*  PHI  56.0
# 4        Shohei Ohtani*  LAD  55.0
# 25          Aaron Judge  NYY  53.0
# 36       Eugenio Suárez  2TM  49.0
# ..                  ...  ...   ...
# 221       Corey Seager*  TEX  21.0
# 245    Ronald Acuña Jr.  ATL  21.0
# 81        Marcell Ozuna  ATL  21.0
# 344  Colson Montgomery*  CHW  21.0
# 106       Spencer Steer  CIN  21.0
#
# [84 rows x 3 columns]

# %%
df.groupby('Team')['HR'].sum().sort_values(ascending=False)
# Out:
# Team
# 2TM    505.0
# NYY    274.0
# LAD    244.0
# SEA    238.0
# LAA    226.0
# NYM    224.0
# CHC    223.0
# ATH    219.0
# ARI    214.0
# PHI    212.0
# DET    198.0
# BAL    191.0
# TOR    191.0
# MIN    191.0
# ATL    190.0
# BOS    186.0
# HOU    182.0
# TBR    182.0
# TEX    175.0
# SFG    173.0
# CLE    168.0
# CIN    167.0
# MIL    166.0
# CHW    165.0
# WSN    161.0
# COL    160.0
# KCR    159.0
# MIA    154.0
# SDP    152.0
# STL    148.0
# PIT    117.0
# 3TM      0.0
# Name: HR, dtype: float64

# %%
df['H'].plot(kind='kde')
# Explain kde plot in 3 sentences
# A KDE (Kernel Density Estimate) plot is a way to visualize the distribution of a continuous variable. It estimates the probability density function of the variable, providing a smooth curve that represents the data distribution. This type of plot is useful for identifying patterns, such as skewness or multimodality, in the data.
# Out:
# <Axes: ylabel='Density'>

# %%
#•	Find the top 5% of players in HR for the 2025 season
hr_threshold = df['HR'].quantile(0.95)
top_5_percent_hr = df[df['HR'] > hr_threshold]
top_5_percent_hr[['Player', 'HR']]
# Out:
#                    Player    HR
# 0       Francisco Lindor#  31.0
# 1          Rafael Devers*  35.0
# 4          Shohei Ohtani*  55.0
# 5             Matt Olson*  29.0
# 6         Kyle Schwarber*  56.0
# 8              Juan Soto*  43.0
# 9         Julio Rodríguez  32.0
# 10            Pete Alonso  38.0
# 11        Randy Arozarena  27.0
# 12           Cal Raleigh#  60.0
# 14           Brent Rooker  30.0
# 19            James Wood*  31.0
# 21           Willy Adames  30.0
# 23    Vinnie Pasquantino*  32.0
# 25            Aaron Judge  53.0
# 26          Manny Machado  27.0
# 28          José Ramírez#  30.0
# 33            Taylor Ward  36.0
# 36         Eugenio Suárez  49.0
# 37         Eugenio Suárez  36.0
# 39        Cody Bellinger*  29.0
# 40          Riley Greene*  36.0
# 45        Junior Caminero  45.0
# 49           Seiya Suzuki  32.0
# 52      Spencer Torkelson  31.0
# 53   Pete Crow-Armstrong*  31.0
# 55      Christian Yelich*  29.0
# 56        Corbin Carroll*  31.0
# ...

# %%
# Write a 3-sentence explanation of regression to the mean 
#Regression to the mean is a statistical phenomenon where extreme values tend to move towards the average over time. In sports, this means that players who perform exceptionally well in one season are likely to perform closer to their average in the following season. This concept is important for understanding performance trends and avoiding overinterpretation of single-season achievements.

# %%
from pybaseball import batting_stats_bref
df1 = batting_stats_bref(2025)
df1.head()
# Out:
#                       Name  Age  #days     Lev          Tm    G   PA   AB   R  \
# 1                CJ Abrams   24    216  Maj-NL  Washington  144  635  580  92
# 2             Wilyer Abreu   26    212  Maj-AL      Boston  116  422  378  53
# 3            Maximo Acosta   22    230  Maj-NL       Miami   19   61   54   7
# 4   Luisangel Acu\xc3\xb1a   23    217  Maj-NL    New York   95  193  175  30
# 5  Ronald Acu\xc3\xb1a Jr.   27    216  Maj-NL     Atlanta   95  412  338  74
#
#      H  ...  SH  SF  GDP  SB  CS     BA    OBP    SLG    OPS   mlbID
# 1  149  ...   1   3    5  31   3  0.257  0.315  0.433  0.748  682928
# 2   92  ...   1   3    8   6   3  0.243  0.314  0.463  0.777  677800
# 3   11  ...   0   0    0   1   2  0.204  0.295  0.389  0.684  691185
# 4   41  ...   2   1    6  16   1  0.234  0.293  0.274  0.567  682668
# 5   98  ...   0   0    5   9   1  0.290  0.417  0.518  0.935  660670
#
# [5 rows x 28 columns]

# %%
df1.columns
# Out:
# Index(['Name', 'Age', '#days', 'Lev', 'Tm', 'G', 'PA', 'AB', 'R', 'H', '2B',
#        '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'GDP', 'SB',
#        'CS', 'BA', 'OBP', 'SLG', 'OPS', 'mlbID'],
#       dtype='object')

# %%
# %pip install nba_api
# Out:
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nba_api]m1/2 [nba_api]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import leaguedashplayerstats
import pandas as pd

nba_df = leaguedashplayerstats.LeagueDashPlayerStats(season='2024-25').get_data_frames()[0]
nba_df.head()
# Out:
#    PLAYER_ID    PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 0    1630639    A.J. Lawson     A.J.  1610612761               TOR  24.0  26
# 1    1631260       AJ Green       AJ  1610612749               MIL  25.0  73
# 2    1642358     AJ Johnson       AJ  1610612764               WAS  20.0  29
# 3     203932   Aaron Gordon    Aaron  1610612743               DEN  29.0  51
# 4    1628988  Aaron Holiday    Aaron  1610612745               HOU  28.0  62
#
#     W   L  W_PCT  ...  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  14  12  0.538  ...        241      200       327       337
# 1  44  29  0.603  ...         99      498       290       214
# 2   8  21  0.276  ...        312      217       369       347
# 3  33  18  0.647  ...        451      301       107       139
# 4  39  23  0.629  ...        224      259       292       292
#
#    PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0              299                   375       159        44
# ...

# %%
nba_df.columns
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'AGE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#        'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#        'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#        'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK', 'TEAM_COUNT'],
#       dtype='object')

# %%
nba_df.describe()
# Out:
#           PLAYER_ID       TEAM_ID         AGE          GP           W  \
# count  5.690000e+02  5.690000e+02  569.000000  569.000000  569.000000
# mean   1.434007e+06  1.610613e+09   26.230228   46.231986   23.235501
# std    4.963906e+05  8.626873e+00    4.220348   24.357135   15.596499
# min    2.544000e+03  1.610613e+09   19.000000    1.000000    0.000000
# 25%    1.628415e+06  1.610613e+09   23.000000   25.000000   10.000000
# 50%    1.630288e+06  1.610613e+09   25.000000   50.000000   21.000000
# 75%    1.631301e+06  1.610613e+09   29.000000   68.000000   36.000000
# max    1.642530e+06  1.610613e+09   40.000000   82.000000   64.000000
#
#                 L       W_PCT          MIN         FGM          FGA  ...  \
# count  569.000000  569.000000   569.000000  569.000000   569.000000  ...
# mean    22.996485    0.486895  1043.233743  180.256591   385.811951  ...
# std     13.985404    0.202094   805.522063  171.087792   357.219330  ...
# ...

# %%
nba_df.groupby('TEAM_ABBREVIATION')['FG3_PCT'].mean()
# Out:
# TEAM_ABBREVIATION
# ATL    0.343278
# BKN    0.307900
# BOS    0.294941
# CHA    0.319429
# CHI    0.322400
# CLE    0.307833
# DAL    0.295526
# DEN    0.301059
# DET    0.272722
# GSW    0.277000
# HOU    0.298833
# IND    0.270952
# LAC    0.338056
# LAL    0.247143
# MEM    0.307579
# MIA    0.340263
# MIL    0.293053
# MIN    0.281050
# NOP    0.303095
# NYK    0.277889
# OKC    0.321333
# ORL    0.289687
# PHI    0.299304
# PHX    0.289222
# POR    0.294158
# SAC    0.323450
# SAS    0.281895
# TOR    0.271950
# UTA    0.299333
# WAS    0.304579
# Name: FG3_PCT, dtype: float64
